# %% [markdown]
# # Introduction
# In this tutorial, we will train a regression model with Foreshadow using the [House Pricing](https://www.kaggle.com/c/house-prices-advanced-regression-techniques) dataset from Kaggle.
#
#
# # Getting Started
# To get started with foreshadow, install the package using `pip install foreshadow`. This will also install the dependencies. Now create a simple python script that uses all the defaults with Foreshadow. Note that Foreshadow requires `Python >=3.6, <4.0`.
#
# First import foreshadow related classes. Also import sklearn, pandas and numpy packages.

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.metrics import get_scorer
from sklearn.metrics import mean_squared_log_error

from foreshadow import Foreshadow
from foreshadow.intents import IntentType
from foreshadow.utils import ProblemType

pd.options.display.max_columns=None

RANDOM_SEED=42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # Load the dataset

# %%
df_train = pd.read_csv("train.csv")
X_df = df_train.drop(columns="SalePrice")
y_df = df_train[["SalePrice"]]
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2)
X_train.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 254    255          20       RL         70.0     8400   Pave   NaN      Reg
# 1066  1067          60       RL         59.0     7837   Pave   NaN      IR1
# 638    639          30       RL         67.0     8777   Pave   NaN      Reg
# 799    800          50       RL         60.0     7200   Pave   NaN      Reg
# 380    381          50       RL         50.0     5000   Pave  Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 254          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1066         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 638          Lvl    AllPub    Inside       Gtl      Edwards      Feedr
# 799          Lvl    AllPub    Corner       Gtl        SWISU      Feedr
# 380          Lvl    AllPub    Inside       Gtl        SWISU       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 254        Norm     1Fam     1Story            5            6       1957
# 1066       Norm     1Fam     2Story            6            7       1993
# 638        Norm     1Fam     1Story            5            7       1910
# 799        Norm     1Fam     1.5Fin            5            7       1937
# 380        Norm     1Fam     1.5Fin            5            6       1924
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 254           1957     Gable  CompShg     MetalSd     MetalSd       None
# 1066          1994     Gable  CompShg     VinylSd     VinylSd       None
# 638           1950     Gable  CompShg     MetalSd     Wd Sdng       None
# 799           1950     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 380           1950     Gable  CompShg     BrkFace     Wd Sdng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 254          0.0        TA        Gd     CBlock       TA       TA
# 1066         0.0        Gd        TA      PConc       Gd       TA
# 638          0.0        TA        TA     CBlock       Fa       TA
# 799        252.0        TA        TA     BrkTil       Gd       TA
# 380          0.0        TA        TA     BrkTil       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 254            No          Rec         922          Unf           0
# 1066           No          Unf           0          Unf           0
# 638            No          Unf           0          Unf           0
# 799            No          ALQ         569          Unf           0
# 380            No          LwQ         218          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 254         392         1314    GasA        TA          Y      SBrkr
# 1066        799          799    GasA        Gd          Y      SBrkr
# 638         796          796    GasA        Gd          Y      FuseA
# 799         162          731    GasA        Ex          Y      SBrkr
# 380         808         1026    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 254       1314         0             0       1314             1             0
# 1066       799       772             0       1571             0             0
# 638        796         0             0        796             0             0
# 799        981       787             0       1768             1             0
# 380       1026       665             0       1691             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 254          1         0             3             1          TA
# 1066         2         1             3             1          TA
# 638          1         0             2             1          TA
# 799          1         1             3             1          Gd
# 380          2         0             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 254              5        Typ           0         NaN     Attchd       1957.0
# 1066             7        Typ           1          TA     Attchd       1993.0
# 638              4        Typ           0         NaN        NaN          NaN
# 799              7        Typ           2          TA     Detchd       1939.0
# 380              6        Typ           1          Gd     Detchd       1924.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 254           RFn           1         294         TA         TA          Y
# 1066          RFn           2         380         TA         TA          Y
# 638           NaN           0           0        NaN        NaN          P
# 799           Unf           1         240         TA         TA          Y
# 380           Unf           1         308         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 254          250            0              0          0            0
# 1066           0           40              0          0            0
# 638          328            0            164          0            0
# 799            0            0            264          0            0
# 380            0            0            242          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 254          0    NaN    NaN         NaN        0       6    2010       WD
# 1066         0    NaN    NaN         NaN        0       5    2009       WD
# 638          0    NaN  MnPrv         NaN        0       5    2008       WD
# 799          0    NaN  MnPrv         NaN        0       6    2007       WD
# 380          0    NaN    NaN         NaN        0       5    2010       WD
#
#      SaleCondition
# 254         Normal
# 1066        Normal
# 638         Normal
# 799         Normal
# 380         Normal

# %% [markdown]
# # Model Training Iteration 1 - ElasticNet

# %%
def measure(model, X_test, y_test):
    y_pred = model.predict(X_test)
    rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))
    print('root mean squared log error = %5.4f' % rmsle)
    return rmsle

# %%
shadow1 = Foreshadow(problem_type=ProblemType.REGRESSION, random_state=RANDOM_SEED, n_jobs=-1, estimator=ElasticNet(random_state=RANDOM_SEED))
_ = shadow1.fit(X_train, y_train)
# Out:
# 2020-04-19 11:53:26,714 - foreshadow - INFO - 71127 - Identified columns with over 90% missing values: Alley,PoolQC,MiscFeature and they will be dropped.
# 2020-04-19 11:53:41,483 - foreshadow - INFO - 71127 - Exported processed data to processed_training_data.csv
# /Users/jichaozhang/PycharmProjects/foreshadow/foreshadow/utils/validation.py:91: UserWarning: Columns are not all uniquely named, automatically resolving
#   "Columns are not all uniquely named, automatically resolving"

# %%
_ = measure(shadow1, X_test, y_test)
# Out:
# 2020-04-19 11:53:45,263 - foreshadow - INFO - 71127 - Exported processed data to processed_test_data.csv
# root mean squared log error = 0.1794
# /Users/jichaozhang/PycharmProjects/foreshadow/foreshadow/utils/validation.py:91: UserWarning: Columns are not all uniquely named, automatically resolving
#   "Columns are not all uniquely named, automatically resolving"

# %% [markdown]
# ### You might be curious how Foreshadow handled the input data. Let's take a look

# %%
shadow1.get_data_summary()
# Out:
#                    SaleCondition     Exterior2nd      MasVnrType  \
# intent               Categorical     Categorical     Categorical
# count                       1168            1168            1168
# nan_percent                    0               0        0.513699
# unique                         6              16               4
# #1_value           Normal 82.53%  VinylSd 35.10%     None 57.96%
# #2_value          Partial 90.92%  Wd Sdng 49.23%  BrkFace 89.30%
# #3_value          Abnorml 97.52%  MetalSd 63.36%    Stone 98.37%
# #4_value           Family 99.06%  HdBoard 77.31%   BrkCmn 99.49%
# #5_value           Alloca 99.66%  Plywood 86.90%
# #6_value         AdjLand 100.00%  CmentBd 90.67%
# #7_value                          Wd Shng 93.58%
# #8_value                           Stucco 95.55%
# #9_value                          AsbShng 97.00%
# #10_value                         BrkFace 98.29%
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                      GarageType  FireplaceQu   Fireplaces     Foundation  \
# intent              Categorical  Categorical  Categorical    Categorical
# count                      1168         1168         1168           1168
# nan_percent             5.47945      46.8322            0              0
# unique                        6            5            4              6
# #1_value          Attchd 59.33%    Gd 26.11%     0 46.83%   PConc 44.52%
# #2_value          Detchd 85.70%    TA 47.69%     1 91.70%  CBlock 87.67%
# #3_value         BuiltIn 92.04%    Fa 50.00%     2 99.66%  BrkTil 97.60%
# #4_value         Basment 93.41%    Ex 51.80%    3 100.00%    Slab 99.32%
# #5_value         CarPort 94.01%    Po 53.17%                Stone 99.74%
# #6_value          2Types 94.52%                             Wood 100.00%
# #7_value
# #8_value
# #9_value
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                     BsmtQual     BsmtCond     Exterior1st BsmtExposure  \
# intent           Categorical  Categorical     Categorical  Categorical
# count                   1168         1168            1168         1168
# nan_percent          2.39726      2.39726               0      2.39726
# unique                     4            4              15            4
# #1_value           TA 44.61%    TA 89.47%  VinylSd 35.96%    No 65.84%
# #2_value           Gd 86.82%    Gd 94.18%  HdBoard 51.03%    Av 80.82%
# #3_value           Ex 95.12%    Fa 97.52%  MetalSd 65.84%    Gd 89.64%
# #4_value           Fa 97.60%    Po 97.60%  Wd Sdng 80.48%    Mn 97.60%
# #5_value                                   Plywood 87.41%
# #6_value                                   CemntBd 91.27%
# #7_value                                   BrkFace 94.69%
# #8_value                                    Stucco 96.49%
# #9_value                                   WdShing 98.12%
# #10_value                                  AsbShng 99.49%
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                   Functional BsmtFinType2 KitchenAbvGr BedroomAbvGr  \
# intent           Categorical  Categorical  Categorical  Categorical
# count                   1168         1168         1168         1168
# nan_percent                0      2.39726            0            0
# unique                     7            6            4            8
# #1_value          Typ 92.81%   Unf 86.39%     1 95.21%     3 55.57%
# #2_value         Min2 95.29%   Rec 90.33%     2 99.74%     2 79.54%
# #3_value         Min1 97.69%   LwQ 93.41%     3 99.91%     4 94.86%
# #4_value          Mod 98.80%   BLQ 95.29%    0 100.00%     1 97.77%
# #5_value         Maj1 99.57%   ALQ 96.75%                  5 99.06%
# #6_value         Maj2 99.91%   GLQ 97.60%                  6 99.57%
# #7_value         Sev 100.00%                               0 99.91%
# #8_value                                                  8 100.00%
# #9_value
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                      SaleType     HalfBath   CentralAir     FullBath  \
# intent            Categorical  Categorical  Categorical  Categorical
# count                    1168         1168         1168         1168
# nan_percent                 0            0            0            0
# unique                      9            3            2            4
# #1_value            WD 86.64%     0 62.50%     Y 92.89%     2 53.51%
# #2_value           New 94.95%     1 99.32%    N 100.00%     1 97.26%
# #3_value           COD 98.03%    2 100.00%                  3 99.57%
# #4_value         ConLD 98.63%                              0 100.00%
# #5_value         ConLw 98.97%
# #6_value           CWD 99.32%
# #7_value         ConLI 99.66%
# #8_value           Oth 99.83%
# #9_value          Con 100.00%
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                 BsmtFinType1 BsmtHalfBath         RoofMatl YearRemodAdd  \
# intent           Categorical  Categorical      Categorical  Categorical
# count                   1168         1168             1168         1168
# nan_percent          2.39726            0                0            0
# unique                     6            3                7           61
# #1_value          Unf 29.54%     0 94.35%   CompShg 98.37%  1950 12.33%
# #2_value          GLQ 57.62%     1 99.91%   Tar&Grv 99.14%  2006 18.92%
# #3_value          ALQ 72.86%    2 100.00%   WdShngl 99.49%  2005 24.23%
# #4_value          BLQ 83.39%                WdShake 99.74%  2007 29.28%
# #5_value          Rec 92.29%                   Roll 99.83%  2004 33.39%
# #6_value          LwQ 97.60%                  Metal 99.91%  2003 36.90%
# #7_value                                   ClyTile 100.00%  2000 40.41%
# #8_value                                                    2002 43.66%
# #9_value                                                    1996 46.49%
# #10_value                                                   2008 49.23%
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                        YrSold         MSZoning         Fence   PavedDrive  \
# intent            Categorical      Categorical   Categorical  Categorical
# count                    1168             1168          1168         1168
# nan_percent                 0                0       80.0514            0
# unique                      5                5             4            3
# #1_value          2009 23.63%        RL 79.11%  MnPrv 10.96%     Y 91.61%
# #2_value          2007 45.89%        RM 93.84%  GdPrv 15.24%     N 97.86%
# #3_value          2006 67.29%        FV 98.37%   GdWo 19.18%    P 100.00%
# #4_value          2008 88.36%        RH 99.66%   MnWw 19.95%
# #5_value         2010 100.00%  C (all) 100.00%
# #6_value
# #7_value
# #8_value
# #9_value
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                   GarageCond   GarageQual  LandContour   GarageCars  \
# intent           Categorical  Categorical  Categorical  Categorical
# count                   1168         1168         1168         1168
# nan_percent          5.47945      5.47945            0            0
# unique                     5            5            4            5
# #1_value           TA 90.84%    TA 89.90%   Lvl 90.67%     2 57.96%
# #2_value           Fa 93.15%    Fa 92.98%   Bnk 94.78%     1 81.85%
# #3_value           Gd 93.92%    Gd 94.09%   HLS 97.77%     3 94.18%
# #4_value           Po 94.35%    Ex 94.35%  Low 100.00%     0 99.66%
# #5_value           Ex 94.52%    Po 94.52%                 4 100.00%
# #6_value
# #7_value
# #8_value
# #9_value
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                       RoofStyle       LotConfig    Neighborhood  \
# intent              Categorical     Categorical     Categorical
# count                      1168            1168            1168
# nan_percent                   0               0               0
# unique                        6               5              25
# #1_value           Gable 77.57%   Inside 70.38%    NAmes 15.50%
# #2_value             Hip 97.69%   Corner 89.30%  CollgCr 25.34%
# #3_value            Flat 98.63%  CulDSac 96.49%  OldTown 33.13%
# #4_value         Gambrel 99.40%      FR2 99.74%  Edwards 40.58%
# #5_value         Mansard 99.83%     FR3 100.00%  Somerst 46.49%
# #6_value           Shed 100.00%                   NWAmes 52.14%
# #7_value                                         Gilbert 57.71%
# #8_value                                         NridgHt 62.93%
# #9_value                                          Sawyer 67.89%
# #10_value                                        BrkSide 71.75%
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                     Condition1     Condition2        BldgType      HouseStyle  \
# intent             Categorical    Categorical     Categorical     Categorical
# count                     1168           1168            1168            1168
# nan_percent                  0              0               0               0
# unique                       9              8               5               8
# #1_value           Norm 85.96%    Norm 99.06%     1Fam 83.73%   1Story 49.40%
# #2_value          Feedr 91.61%   Feedr 99.32%   TwnhsE 91.27%   2Story 80.22%
# #3_value         Artery 95.03%  Artery 99.49%   Duplex 94.78%   1.5Fin 90.58%
# #4_value           RRAn 96.66%    PosN 99.66%    Twnhs 97.52%     SLvl 95.03%
# #5_value           PosN 97.95%    PosA 99.74%  2fmCon 100.00%   SFoyer 97.43%
# #6_value           RRAe 98.80%    RRAn 99.83%                   1.5Unf 98.46%
# #7_value           PosA 99.49%    RRNn 99.91%                   2.5Unf 99.40%
# #8_value           RRNn 99.91%   RRAe 100.00%                  2.5Fin 100.00%
# #9_value          RRNe 100.00%
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                 GarageFinish  OverallCond    YearBuilt    LandSlope  \
# intent           Categorical  Categorical  Categorical  Categorical
# count                   1168         1168         1168         1168
# nan_percent          5.47945            0            0            0
# unique                     3            9          111            3
# #1_value          Unf 41.10%     5 56.25%   2006 4.45%   Gtl 94.86%
# #2_value          RFn 70.12%     6 73.89%   2005 8.90%   Mod 99.23%
# #3_value          Fin 94.52%     7 87.76%  2004 12.84%  Sev 100.00%
# #4_value                         8 92.47%  2007 16.10%
# #5_value                         4 96.23%  2003 19.18%
# #6_value                         9 98.03%  1976 21.32%
# #7_value                         3 99.57%  1977 23.37%
# #8_value                         2 99.91%  1920 25.26%
# #9_value                        1 100.00%  1965 27.05%
# #10_value                                  1998 28.85%
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                 BsmtFullBath KitchenQual          Id       Utilities  \
# intent           Categorical   Droppable   Droppable       Droppable
# count                   1168        1168        1168            1168
# nan_percent                0           0           0               0
# unique                     4           4        1168               2
# #1_value            0 58.65%   TA 50.43%  1460 0.09%   AllPub 99.91%
# #2_value            1 98.89%   Gd 90.67%   498 0.17%  NoSeWa 100.00%
# #3_value            2 99.91%   Ex 97.26%   478 0.26%
# #4_value           3 100.00%  Fa 100.00%   481 0.34%
# #5_value                                   482 0.43%
# #6_value                                   483 0.51%
# #7_value                                   484 0.60%
# #8_value                                   485 0.68%
# #9_value                                   486 0.77%
# #10_value                                  487 0.86%
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                        Street     LotShape   ExterQual   ExterCond  \
# intent              Droppable    Droppable   Droppable   Droppable
# count                    1168         1168        1168        1168
# nan_percent                 0            0           0           0
# unique                      2            4           4           5
# #1_value          Pave 99.66%   Reg 62.41%   TA 62.24%   TA 87.16%
# #2_value         Grvl 100.00%   IR1 96.15%   Gd 95.46%   Gd 97.60%
# #3_value                        IR2 99.32%   Ex 99.06%   Fa 99.66%
# #4_value                       IR3 100.00%  Fa 100.00%   Ex 99.91%
# #5_value                                                Po 100.00%
# #6_value
# #7_value
# #8_value
# #9_value
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                        Heating   HeatingQC    Electrical  \
# intent               Droppable   Droppable     Droppable
# count                     1168        1168          1168
# nan_percent                  0           0     0.0856164
# unique                       6           5             4
# #1_value           GasA 97.60%   Ex 49.91%  SBrkr 91.70%
# #2_value           GasW 98.89%   TA 79.62%  FuseA 97.60%
# #3_value           Grav 99.40%   Gd 96.32%  FuseF 99.66%
# #4_value           Wall 99.74%   Fa 99.91%  FuseP 99.91%
# #5_value           OthW 99.91%  Po 100.00%
# #6_value         Floor 100.00%
# #7_value
# #8_value
# #9_value
# #10_value
# invalid_percent
# mean
# std
# min
# 25%
# 50%
# 75%
# max
# 5_outliers
#
#                                       BsmtUnfSF                 MSSubClass  \
# intent                                  Numeric                    Numeric
# count                                      1168                       1168
# nan_percent                                   0                          0
# unique                                      685                         15
# #1_value                                0 7.88%                  20 37.16%
# #2_value                              728 8.48%                  60 57.71%
# #3_value                              572 9.08%                  50 67.38%
# #4_value                              300 9.59%                 120 72.86%
# #5_value                             625 10.10%                  70 77.31%
# #6_value                             672 10.62%                  30 81.59%
# #7_value                             600 11.13%                 160 85.79%
# #8_value                             384 11.64%                  80 89.64%
# #9_value                             490 12.07%                  90 93.15%
# #10_value                            280 12.50%                 190 95.55%
# invalid_percent                               0                          0
# mean                                    570.595                    56.8493
# std                                     446.365                    42.5319
# min                                           0                         20
# 25%                                       222.5                         20
# 50%                                         480                         50
# 75%                                      810.25                         70
# max                                        2336                        190
# 5_outliers       [2336, 2153, 2121, 2046, 2002]  [190, 190, 190, 190, 190]
#
#                     MoSold                          MiscVal  \
# intent             Numeric                          Numeric
# count                 1168                             1168
# nan_percent              0                                0
# unique                  12                               19
# #1_value          6 17.64%                         0 96.23%
# #2_value          7 33.73%                       400 96.92%
# #3_value          5 48.97%                       500 97.60%
# #4_value          4 58.13%                       700 98.03%
# #5_value          8 66.10%                       450 98.37%
# #6_value          3 73.29%                      2000 98.72%
# #7_value         10 79.28%                      1200 98.89%
# #8_value         11 85.10%                       480 99.06%
# #9_value          9 89.30%                      1150 99.14%
# #10_value        12 93.24%                       800 99.23%
# invalid_percent          0                                0
# mean               6.35616                          51.2671
# std                2.67071                           553.04
# min                      1                                0
# 25%                      5                                0
# 50%                      6                                0
# 75%                      8                                0
# max                     12                            15500
# 5_outliers              []  [15500, 8300, 3500, 2500, 2000]
#
#                                          LotFrontage  \
# intent                                       Numeric
# count                                           1168
# nan_percent                                  18.5788
# unique                                           107
# #1_value                                  60.0 9.59%
# #2_value                                 70.0 14.47%
# #3_value                                 80.0 19.09%
# #4_value                                 50.0 23.12%
# #5_value                                 75.0 26.71%
# #6_value                                 65.0 29.71%
# #7_value                                 85.0 32.45%
# #8_value                                 78.0 34.25%
# #9_value                                 90.0 35.87%
# #10_value                                21.0 37.33%
# invalid_percent                                    0
# mean                                         70.3438
# std                                           24.897
# min                                               21
# 25%                                               59
# 50%                                               70
# 75%                                               80
# max                                              313
# 5_outliers       [313.0, 313.0, 182.0, 174.0, 168.0]
#
#                                   PoolArea                ScreenPorch  \
# intent                             Numeric                    Numeric
# count                                 1168                       1168
# nan_percent                              0                          0
# unique                                   7                         66
# #1_value                          0 99.49%                   0 91.70%
# #2_value                        738 99.57%                 192 92.21%
# #3_value                        648 99.66%                 224 92.55%
# #4_value                        555 99.74%                 120 92.89%
# #5_value                        519 99.83%                 180 93.24%
# #6_value                        512 99.91%                 189 93.58%
# #7_value                       480 100.00%                  90 93.84%
# #8_value                                                   126 94.09%
# #9_value                                                   168 94.35%
# #10_value                                                  100 94.52%
# invalid_percent                          0                          0
# mean                               2.95548                    15.4075
# std                                41.6485                    55.8811
# min                                      0                          0
# 25%                                      0                          0
# 50%                                      0                          0
# 75%                                      0                          0
# max                                    738                        480
# 5_outliers       [738, 648, 555, 519, 512]  [480, 440, 410, 385, 374]
#
#                                  3SsnPorch              EnclosedPorch  \
# intent                             Numeric                    Numeric
# count                                 1168                       1168
# nan_percent                              0                          0
# unique                                  17                         98
# #1_value                          0 98.29%                   0 86.30%
# #2_value                        180 98.46%                 112 87.41%
# #3_value                        144 98.63%                  96 87.93%
# #4_value                        216 98.80%                 216 88.27%
# #5_value                        168 98.97%                 192 88.61%
# #6_value                        130 99.06%                 144 88.96%
# #7_value                        140 99.14%                 252 89.30%
# #8_value                        153 99.23%                 120 89.64%
# #9_value                        162 99.32%                 184 89.90%
# #10_value                       508 99.40%                  40 90.15%
# invalid_percent                          0                          0
# mean                                3.8125                     21.839
# std                                31.5197                    62.0832
# min                                      0                          0
# 25%                                      0                          0
# 50%                                      0                          0
# 75%                                      0                          0
# max                                    508                        552
# 5_outliers       [508, 407, 320, 304, 290]  [552, 386, 330, 301, 293]
#
#                                OpenPorchSF                 WoodDeckSF  \
# intent                             Numeric                    Numeric
# count                                 1168                       1168
# nan_percent                              0                          0
# unique                                 188                        244
# #1_value                          0 43.84%                   0 52.91%
# #2_value                         36 45.89%                 192 55.39%
# #3_value                         20 47.35%                 144 57.71%
# #4_value                         40 48.63%                 100 59.85%
# #5_value                         48 49.83%                 120 61.99%
# #6_value                         45 51.03%                 168 63.78%
# #7_value                         60 52.14%                 224 64.90%
# #8_value                         39 53.17%                 140 65.92%
# #9_value                         30 54.20%                 240 66.61%
# #10_value                        98 55.14%                 160 67.21%
# invalid_percent                          0                          0
# mean                               49.5788                    95.9469
# std                                69.4336                    129.686
# min                                      0                          0
# 25%                                      0                          0
# 50%                                     27                          0
# 75%                                     74                        168
# max                                    547                        857
# 5_outliers       [547, 523, 502, 418, 406]  [857, 736, 728, 670, 668]
#
#                            2ndFlrSF                     TotalBsmtSF  \
# intent                      Numeric                         Numeric
# count                          1168                            1168
# nan_percent                       0                               0
# unique                          361                             630
# #1_value                   0 56.25%                         0 2.40%
# #2_value                 504 56.93%                       864 4.62%
# #3_value                 728 57.53%                       672 5.91%
# #4_value                 720 58.13%                       912 7.11%
# #5_value                 546 58.73%                      1040 7.96%
# #6_value                 672 59.25%                       816 8.82%
# #7_value                 862 59.67%                       768 9.59%
# #8_value                 600 60.10%                      780 10.36%
# #9_value                 551 60.45%                      728 11.13%
# #10_value                780 60.79%                      894 11.82%
# invalid_percent                   0                               0
# mean                        352.351                         1061.77
# std                         439.571                         440.676
# min                               0                               0
# 25%                               0                             796
# 50%                               0                           997.5
# 75%                             728                         1299.25
# max                            2065                            6110
# 5_outliers       [2065, 1818, 1796]  [6110, 3200, 3138, 3094, 2633]
#
#                                        1stFlrSF  \
# intent                                  Numeric
# count                                      1168
# nan_percent                                   0
# unique                                      657
# #1_value                              864 1.80%
# #2_value                              912 2.91%
# #3_value                             1040 3.94%
# #4_value                              672 4.71%
# #5_value                              848 5.39%
# #6_value                              894 6.08%
# #7_value                              960 6.68%
# #8_value                              816 7.28%
# #9_value                              483 7.79%
# #10_value                             764 8.30%
# invalid_percent                               0
# mean                                    1169.35
# std                                     386.675
# min                                         334
# 25%                                         888
# 50%                                        1095
# 75%                                     1396.75
# max                                        4692
# 5_outliers       [4692, 3228, 3138, 2633, 2524]
#
#                                      GarageArea               LowQualFinSF  \
# intent                                  Numeric                    Numeric
# count                                      1168                       1168
# nan_percent                                   0                          0
# unique                                      394                         20
# #1_value                                0 5.48%                   0 98.20%
# #2_value                              440 8.73%                  80 98.46%
# #3_value                             576 11.90%                 528 98.54%
# #4_value                             528 14.38%                  53 98.63%
# #5_value                             240 16.78%                 120 98.72%
# #6_value                             484 19.01%                 144 98.80%
# #7_value                             288 20.72%                 205 98.89%
# #8_value                             400 22.35%                 232 98.97%
# #9_value                             480 23.97%                 234 99.06%
# #10_value                            264 25.43%                 360 99.14%
# invalid_percent                               0                          0
# mean                                    476.274                    5.69606
# std                                     211.095                    47.8871
# min                                           0                          0
# 25%                                         341                          0
# 50%                                         482                          0
# 75%                                         576                          0
# max                                        1418                        572
# 5_outliers       [1418, 1356, 1220, 1166, 1134]  [572, 528, 515, 513, 481]
#
#                 OverallQual    GarageYrBlt  \
# intent              Numeric        Numeric
# count                  1168           1168
# nan_percent               0        5.47945
# unique                   10             94
# #1_value           6 26.63%   2005.0 4.45%
# #2_value           5 53.00%   2006.0 8.30%
# #3_value           7 75.09%  2004.0 12.16%
# #4_value           8 86.64%  2007.0 15.58%
# #5_value           4 94.18%  2003.0 19.01%
# #6_value           9 97.26%  1998.0 21.32%
# #7_value           3 98.63%  1977.0 23.46%
# #8_value          10 99.74%  1999.0 25.51%
# #9_value           1 99.91%  2000.0 27.48%
# #10_value         2 100.00%  2002.0 29.37%
# invalid_percent           0              0
# mean                6.12158        1978.66
# std                 1.36762        24.7289
# min                       1           1900
# 25%                       5        1961.75
# 50%                       6           1980
# 75%                       7           2002
# max                      10           2010
# 5_outliers        [2, 1, 1]       [1900.0]
#
#                                             MasVnrArea  \
# intent                                         Numeric
# count                                             1168
# nan_percent                                   0.513699
# unique                                             286
# #1_value                                    0.0 57.71%
# #2_value                                  108.0 58.30%
# #3_value                                  180.0 58.90%
# #4_value                                  200.0 59.42%
# #5_value                                  120.0 59.93%
# #6_value                                  106.0 60.45%
# #7_value                                   16.0 60.96%
# #8_value                                   72.0 61.47%
# #9_value                                  340.0 61.99%
# #10_value                                 320.0 62.41%
# invalid_percent                                      0
# mean                                           103.772
# std                                            173.032
# min                                                  0
# 25%                                                  0
# 50%                                                  0
# 75%                                                166
# max                                               1378
# 5_outliers       [1378.0, 1047.0, 975.0, 922.0, 921.0]
#
#                                BsmtFinSF1          TotRmsAbvGrd  \
# intent                            Numeric               Numeric
# count                                1168                  1168
# nan_percent                             0                     0
# unique                                549                    12
# #1_value                         0 31.93%              6 27.83%
# #2_value                        24 32.88%              7 50.77%
# #3_value                        16 33.56%              5 69.09%
# #4_value                        20 33.99%              8 82.02%
# #5_value                       936 34.42%              4 88.01%
# #6_value                      1200 34.76%              9 93.58%
# #7_value                       600 35.10%             10 96.75%
# #8_value                       616 35.45%             11 98.03%
# #9_value                       547 35.79%              3 99.06%
# #10_value                      641 36.13%             12 99.83%
# invalid_percent                         0                     0
# mean                              446.024               6.56164
# std                               459.071               1.61971
# min                                     0                     2
# 25%                                     0                     5
# 50%                                 384.5                     6
# 75%                                   721                     7
# max                                  5644                    14
# 5_outliers       [5644, 2260, 2096, 1904]  [14, 12, 12, 12, 12]
#
#                                      BsmtFinSF2  \
# intent                                  Numeric
# count                                      1168
# nan_percent                                   0
# unique                                      118
# #1_value                               0 88.78%
# #2_value                             180 89.21%
# #3_value                             374 89.47%
# #4_value                             279 89.64%
# #5_value                             182 89.81%
# #6_value                             539 89.98%
# #7_value                             468 90.15%
# #8_value                             117 90.33%
# #9_value                             551 90.50%
# #10_value                            290 90.67%
# invalid_percent                               0
# mean                                    45.1524
# std                                     158.217
# min                                           0
# 25%                                           0
# 50%                                           0
# 75%                                           0
# max                                        1127
# 5_outliers       [1127, 1120, 1085, 1080, 1061]
#
#                                                  LotArea  \
# intent                                           Numeric
# count                                               1168
# nan_percent                                            0
# unique                                               890
# #1_value                                      9600 1.97%
# #2_value                                      7200 3.51%
# #3_value                                      6000 4.71%
# #4_value                                     10800 5.82%
# #5_value                                      8400 6.76%
# #6_value                                      9000 7.62%
# #7_value                                      1680 8.30%
# #8_value                                      3182 8.90%
# #9_value                                      9100 9.50%
# #10_value                                    7500 10.10%
# invalid_percent                                        0
# mean                                             10689.6
# std                                              10759.4
# min                                                 1300
# 25%                                              7587.25
# 50%                                                 9600
# 75%                                                11700
# max                                               215245
# 5_outliers       [215245, 164660, 159000, 115149, 63887]
#
#                                       GrLivArea     SalePrice
# intent                                  Numeric         Label
# count                                      1168          1168
# nan_percent                                   0             0
# unique                                      734           571
# #1_value                              864 1.54%  140000 1.28%
# #2_value                             1040 2.48%  135000 2.40%
# #3_value                             1200 3.25%  190000 3.42%
# #4_value                              894 3.94%  110000 4.45%
# #5_value                              912 4.62%  155000 5.39%
# #6_value                              816 5.22%  125000 6.25%
# #7_value                             1728 5.82%  160000 7.11%
# #8_value                             1456 6.42%  145000 7.96%
# #9_value                             1092 7.02%  139000 8.82%
# #10_value                            1494 7.53%  100000 9.59%
# invalid_percent                               0           NaN
# mean                                     1527.4           NaN
# std                                     524.433           NaN
# min                                         334           NaN
# 25%                                     1145.75           NaN
# 50%                                        1473           NaN
# 75%                                        1792           NaN
# max                                        5642           NaN
# 5_outliers       [5642, 4676, 4476, 3627, 3608]           NaN

# %% [markdown]
# #### Foreshadow use a machine learning model to identify the 'intent' of features. 3 intents are supported as of v1.0 and they are 'Categorical', 'Numeric' and 'Text'. Foreshadow will transform the features intelligently according to its intent and statistics. Features not belonging to these three are tagged as 'Droppable'. For example, the Id is droppable since it has a unique value for each row and will not provide any signal to the model. Also in the above table, 'Label' in the intent row indicate that is the target column.

# %% [markdown]
# # Model Training Iteration 2 - Override

# %%
shadow2 = Foreshadow(problem_type=ProblemType.REGRESSION, random_state=RANDOM_SEED, n_jobs=-1, estimator=ElasticNet(random_state=RANDOM_SEED))
shadow2.override_intent('ExterQual', IntentType.CATEGORICAL)
shadow2.override_intent('ExterCond', IntentType.CATEGORICAL)
shadow2.override_intent('LotShape', IntentType.CATEGORICAL)
shadow2.override_intent('HeatingQC', IntentType.CATEGORICAL)
shadow2.override_intent('YearBuilt', IntentType.NUMERIC)
shadow2.override_intent('YearRemodAdd', IntentType.NUMERIC)
shadow2.override_intent('YrSold', IntentType.NUMERIC)
_ = shadow2.fit(X_train, y_train)
# Out:
# 2020-04-19 11:53:45,456 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column ExterQual exist to ensure the override takes effect.
# 2020-04-19 11:53:45,459 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column ExterCond exist to ensure the override takes effect.
# 2020-04-19 11:53:45,461 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column LotShape exist to ensure the override takes effect.
# 2020-04-19 11:53:45,462 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column HeatingQC exist to ensure the override takes effect.
# 2020-04-19 11:53:45,463 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YearBuilt exist to ensure the override takes effect.
# 2020-04-19 11:53:45,464 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YearRemodAdd exist to ensure the override takes effect.
# 2020-04-19 11:53:45,465 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YrSold exist to ensure the override takes effect.
# 2020-04-19 11:53:50,733 - foreshadow - INFO - 71127 - Identified columns with over 90% missing values: Alley,PoolQC,MiscFeature and they will be dropped.
# 2020-04-19 11:54:00,923 - foreshadow - INFO - 71127 - Exported processed data to processed_training_data.csv

# %%
_ = measure(shadow2, X_test, y_test)
# Out:
# 2020-04-19 11:54:02,114 - foreshadow - INFO - 71127 - Exported processed data to processed_test_data.csv
# root mean squared log error = 0.1721

# %% [markdown]
# # Model Training Iteration 3 - AutoEstimator

# %% [markdown]
# #### Instead of trying one estimator, we can leverage AutoEstimator to search ML models and hyper-parameters. When we do not provide an estimator, Foreshadow will create the AutoEstimator automatically.

# %%
shadow3 = Foreshadow(problem_type=ProblemType.REGRESSION, allowed_seconds=300, random_state=RANDOM_SEED, n_jobs=-1)
shadow3.override_intent('ExterQual', IntentType.CATEGORICAL)
shadow3.override_intent('ExterCond', IntentType.CATEGORICAL)
shadow3.override_intent('LotShape', IntentType.CATEGORICAL)
shadow3.override_intent('HeatingQC', IntentType.CATEGORICAL)
shadow3.override_intent('YearBuilt', IntentType.NUMERIC)
shadow3.override_intent('YearRemodAdd', IntentType.NUMERIC)
shadow3.override_intent('YrSold', IntentType.NUMERIC)
_ = shadow3.fit(X_train, y_train)
# Out:
# 2020-04-19 11:54:02,135 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column ExterQual exist to ensure the override takes effect.
# 2020-04-19 11:54:02,137 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column ExterCond exist to ensure the override takes effect.
# 2020-04-19 11:54:02,140 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column LotShape exist to ensure the override takes effect.
# 2020-04-19 11:54:02,142 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column HeatingQC exist to ensure the override takes effect.
# 2020-04-19 11:54:02,143 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YearBuilt exist to ensure the override takes effect.
# 2020-04-19 11:54:02,144 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YearRemodAdd exist to ensure the override takes effect.
# 2020-04-19 11:54:02,145 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YrSold exist to ensure the override takes effect.
# 2020-04-19 11:54:07,792 - foreshadow - INFO - 71127 - Identified columns with over 90% missing values: Alley,PoolQC,MiscFeature and they will be dropped.
# 2020-04-19 11:54:18,778 - foreshadow - INFO - 71127 - Exported processed data to processed_training_data.csv
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', style=ProgressStyle(description_w…
# Generation 1 - Current best internal CV score: -819018849.1253982
#
# 5.02 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestRegressor(RidgeCV(input_matrix), bootstrap=True, max_features=0.5, min_samples_leaf=6, min_samples_split=14, n_estimators=100)

# %%
_ = measure(shadow3, X_test, y_test)
# Out:
# 2020-04-19 11:59:23,264 - foreshadow - INFO - 71127 - Exported processed data to processed_test_data.csv
# root mean squared log error = 0.1483

# %% [markdown]
# # Model Training Iteration 4 - Customize Scoring Function in Search

# %% [markdown]
# #### The Kaggle competition use root mean squared log error to rank result. Let's ask the AutoEstimator to optimize for this scoring function

# %%
shadow4 = Foreshadow(problem_type=ProblemType.REGRESSION, allowed_seconds=300, random_state=RANDOM_SEED, 
                     n_jobs=-1, auto_estimator_kwargs={"scoring": get_scorer('neg_mean_squared_log_error')})
shadow4.override_intent('ExterQual', IntentType.CATEGORICAL)
shadow4.override_intent('ExterCond', IntentType.CATEGORICAL)
shadow4.override_intent('LotShape', IntentType.CATEGORICAL)
shadow4.override_intent('HeatingQC', IntentType.CATEGORICAL)
shadow4.override_intent('YearBuilt', IntentType.NUMERIC)
shadow4.override_intent('YearRemodAdd', IntentType.NUMERIC)
shadow4.override_intent('YrSold', IntentType.NUMERIC)
_ = shadow4.fit(X_train, y_train)
# Out:
# 2020-04-19 11:59:23,300 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column ExterQual exist to ensure the override takes effect.
# 2020-04-19 11:59:23,301 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column ExterCond exist to ensure the override takes effect.
# 2020-04-19 11:59:23,302 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column LotShape exist to ensure the override takes effect.
# 2020-04-19 11:59:23,304 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column HeatingQC exist to ensure the override takes effect.
# 2020-04-19 11:59:23,307 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YearBuilt exist to ensure the override takes effect.
# 2020-04-19 11:59:23,310 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YearRemodAdd exist to ensure the override takes effect.
# 2020-04-19 11:59:23,314 - foreshadow - INFO - 71127 - The foreshadow object is not trained yet. Please make sure the column YrSold exist to ensure the override takes effect.
# 2020-04-19 11:59:27,751 - foreshadow - INFO - 71127 - Identified columns with over 90% missing values: Alley,PoolQC,MiscFeature and they will be dropped.
# 2020-04-19 11:59:34,219 - foreshadow - INFO - 71127 - Exported processed data to processed_training_data.csv
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', style=ProgressStyle(description_w…
# Generation 1 - Current best internal CV score: -0.01865521912350544
#
# 5.11 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestRegressor(ExtraTreesRegressor(RidgeCV(input_matrix), bootstrap=True, max_features=0.8, min_samples_leaf=5, min_samples_split=6, n_estimators=100), bootstrap=True, max_features=0.5, min_samples_leaf=12, min_samples_split=14, n_estimators=100)

# %%
rmsle = measure(shadow4, X_train, y_train)
# Out:
# 2020-04-19 12:04:47,104 - foreshadow - INFO - 71127 - Exported processed data to processed_test_data.csv
# root mean squared log error = 0.0885

# %% [markdown]
# ## Compare Kaggle Leaderboard

# %%
leaderboard = pd.read_csv('house-prices-advanced-regression-techniques-publicleaderboard.csv')
leaderboard.sort_values(by='Score', ascending=True, inplace=True)
better_solutions = leaderboard[leaderboard.Score < rmsle]
ranking = len(better_solutions) * 100.0 / len(leaderboard)
print('Our solution ranked at %dth position within top %0.2f%%' % (len(better_solutions), ranking))
# Out:
# Our solution ranked at 26th position within top 0.19%
